# %%
# Import necessary libraries
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Load dataset
# Assuming that 'data.csv' is your dataset and it's in the same directory
data = pd.read_csv("/home/dev/Documents/Input/ALL CDN Data.csv")
data = data[data["Community"] == "port credit"]
data = data.dropna()

# %%
data.head()
# Out:
#               Address Approx_Square_Footage  Area    Community Last_Status  \
# 786     49 Queen St E             1000-1199  peel  port credit         Sld
# 964      65 Port St E             1600-1799  peel  port credit         Sld
# 1591         8 Ann St             1800-1999  peel  port credit         Sld
# 1783  1 Hurontario St               900-999  peel  port credit         Sld
# 2499  1 Hurontario St             1000-1199  peel  port credit         Sld
#
#      ML_Number Municipality Municipality_District  Sold_Price  Washrooms  ...  \
# 786   W6680290  Mississauga           Mississauga    601000.0          2  ...
# 964   W6730168  Mississauga           Mississauga   1700000.0          3  ...
# 1591  W6778796  Mississauga           Mississauga   1437000.0          3  ...
# 1783  W6805334  Mississauga           Mississauga    693000.0          1  ...
# 2499  W7031522  Mississauga           Mississauga    947000.0          2  ...
#
# ...

# %%
columns = [
    "lat",
    "lng",
    "calculated_Approx_Age",
    "latest_tax",
    "Washrooms",
    "Bedrooms",
    "Bedrooms_",
    "Adjusted_Total_Parking_Spaces",
    "Parking_Category",
    "Modified_Balcony",
    "Approx_Square_Footage",
    "FLOOR_NUMBER",
    "Current_Price",
    "Address",
    "Sold_Month",
]
categorical_columns = [
    "Washrooms",
    "Bedrooms",
    "Adjusted_Total_Parking_Spaces",
    "Parking_Category",
    "Modified_Balcony",
    "FLOOR_NUMBER",
    "calculated_Approx_Age",
    "Approx_Square_Footage",
    # "Address",
    "Bedrooms_",
]
numerical_columns = [
    "latest_tax",
]

data = data[columns]

# %%
data.head()
# Out:
#             lat        lng calculated_Approx_Age   latest_tax  Washrooms  \
# 786   43.555207 -79.587075                 31-50  2556.460000          2
# 964   43.553851 -79.580915                 16-30  8559.740000          3
# 1591  43.555051 -79.583333                   0-5  8604.000000          3
# 1783  43.555963 -79.582234                15-Nov  3840.600000          1
# 2499  43.555963 -79.582234                15-Nov  4644.951635          2
#
#       Bedrooms  Bedrooms_  Adjusted_Total_Parking_Spaces Parking_Category  \
# 786        3.0        0.0                            1.0      Underground
# 964        2.0        1.0                            2.0      Underground
# 1591       3.0        0.0                            2.0      Underground
# 1783       1.0        1.0                            1.0      Underground
# 2499       2.0        0.0                            1.0      Underground
#
#      Modified_Balcony Approx_Square_Footage FLOOR_NUMBER  Current_Price  \
# ...

# %%
for column in categorical_columns:
    label_encoder = LabelEncoder()
    data[column] = label_encoder.fit_transform(data[column])

# %%
 #Preprocessing
# Assuming that the last column is 'price' and the others are features
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Split the dataset into the training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Initialising the MLPRegressor
model = MLPRegressor(hidden_layer_sizes=(32, 32), activation='relu', solver='adam', max_iter=500)

# Fitting the MLPRegressor to the Training set
model.fit(X_train, y_train)

# Predicting the Test set results
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 11
#       9 # Feature Scaling
#      10 sc = StandardScaler()
# ---> 11 X_train = sc.fit_transform(X_train)
#      12 X_test = sc.transform(X_test)
#      14 # Initialising the MLPRegressor
#
# File ~/miniconda3/envs/personal/lib/python3.12/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...
